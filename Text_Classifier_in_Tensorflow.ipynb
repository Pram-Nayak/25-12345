# %% [markdown]
# 1 genetic ,1 naive,1 tensorflow and other from before midterm
#
# answer to scenariow hen questions are like that and generic ,,
#
# for lab exam a variation of notebooks shared, apply knowledgr an ddont copy the entire solution and not LLMs to be used.

# %% [markdown]
# Building a sentiment analysis model for airline tweets using a neural network.
#
#  It preprocesses the data, extracts features, trains the model, evaluates its performance, and analyzes the importance of different words in predicting sentiment.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# Data Loading and Preprocessing:

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks2/NLP/lab8/AirlineTweets.csv')

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df.shape
# Out:
# (14640, 15)

# %%
df['airline_sentiment'].value_counts()
# Out:
# airline_sentiment
# negative    9178
# neutral     3099
# positive    2363
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
#  12  tweet_created                 14640 non-null  object
#  13  tweet_location                9907 non-null   object
#  14  user_timezone                 9820 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 1.7+ MB

# %%
df = df[['airline_sentiment', 'text']]
print(df)
# Out:
#       airline_sentiment                                               text
# 0               neutral                @VirginAmerica What @dhepburn said.
# 1              positive  @VirginAmerica plus you've added commercials t...
# 2               neutral  @VirginAmerica I didn't today... Must mean I n...
# 3              negative  @VirginAmerica it's really aggressive to blast...
# 4              negative  @VirginAmerica and it's a really big bad thing...
# ...                 ...                                                ...
# 14635          positive  @AmericanAir thank you we got on a different f...
# 14636          negative  @AmericanAir leaving over 20 minutes Late Flig...
# 14637           neutral  @AmericanAir Please bring American Airlines to...
# 14638          negative  @AmericanAir you have my money, you change my ...
# 14639           neutral  @AmericanAir we have 8 ppl so we need 2 know h...
#
# [14640 rows x 2 columns]

# %%
df['airline_sentiment'].hist()
# Out:
# <Axes: >

# %% [markdown]
# It removes neutral tweets and converts sentiment labels to numerical targets (1 for positive, 0 for negative).

# %%
df = df[df['airline_sentiment'] != 'neutral'].copy()
print(df)
# Out:
#       airline_sentiment                                               text
# 1              positive  @VirginAmerica plus you've added commercials t...
# 3              negative  @VirginAmerica it's really aggressive to blast...
# 4              negative  @VirginAmerica and it's a really big bad thing...
# 5              negative  @VirginAmerica seriously would pay $30 a fligh...
# 6              positive  @VirginAmerica yes, nearly every time I fly VX...
# ...                 ...                                                ...
# 14633          negative  @AmericanAir my flight was Cancelled Flightled...
# 14634          negative         @AmericanAir right on cue with the delays👌
# 14635          positive  @AmericanAir thank you we got on a different f...
# 14636          negative  @AmericanAir leaving over 20 minutes Late Flig...
# 14638          negative  @AmericanAir you have my money, you change my ...
#
# [11541 rows x 2 columns]

# %%
target_map = {'positive': 1, 'negative': 0}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df.head()
# Out:
#   airline_sentiment                                               text  target
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0
# 5          negative  @VirginAmerica seriously would pay $30 a fligh...       0
# 6          positive  @VirginAmerica yes, nearly every time I fly VX...       1

# %% [markdown]
# Feature Extraction:
#
# It uses TF-IDF (Term Frequency-Inverse Document Frequency) to convert text into numerical features that can be fed into a machine learning model.
#
# This involves creating a vocabulary of important words and calculating their relevance to each tweet.

# %%
df_train, df_test = train_test_split(df, random_state=42)

# %%
vectorizer = TfidfVectorizer(max_features=2000)  # numerical statistic that reflects how important a word is to a document in a collection or corpus.
# limits the vocabulary size to the 2000 most frequent words, reducing the dimensionality of the data.
X_train = vectorizer.fit_transform(df_train['text'])
#fit: It learns the vocabulary and IDF weights from the training data (df_train['text'], which contains the tweet text).
#transform: It transforms the training data into a TF-IDF matrix (X_train), where each row represents a tweet and each column represents a word in the vocabulary. The values in the matrix represent the TF-IDF scores for each word in each tweet.
X_test = vectorizer.transform(df_test['text'])
#This line transforms the testing data (df_test['text']) into a TF-IDF matrix (X_test) using the same vocabulary and IDF weights learned from the training data.
#This ensures that the training and testing data are represented in the same feature space.

# %%
# data must not be sparse matrix before passing into tensorflow
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
Y_train = df_train['target']
Y_test = df_test['target']

# %%
# input dimensions
D = X_train.shape[1]

# %%
# build model
i = Input(shape=(D,))
x = Dense(1)(i) # sigmoid included in loss

model = Model(i, x)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 2000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           2,001 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,001 (7.82 KB)
#  Trainable params: 2,001 (7.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Model Building and Training:
#
#  Building a simple neural network model with one dense layer using TensorFlow.
#
#  It compiles the model with an appropriate loss function (Binary Crossentropy) and optimizer (Adam).
#
#  It trains the model on the training data and validates it on the testing data for a certain number of epochs.

# %%
model.compile(
  loss=BinaryCrossentropy(from_logits=True),
  optimizer=Adam(learning_rate=0.01),
  metrics=['accuracy']
)

# %%
r = model.fit(
  X_train, Y_train,
  validation_data=(X_test, Y_test),
  epochs=40,
  batch_size=128,
)
# Out:
# Epoch 1/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7990 - loss: 0.5708 - val_accuracy: 0.8049 - val_loss: 0.3975
# Epoch 2/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.3820 - val_accuracy: 0.8233 - val_loss: 0.3398
# Epoch 3/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8202 - loss: 0.3243 - val_accuracy: 0.8434 - val_loss: 0.3027
# Epoch 4/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8473 - loss: 0.2848 - val_accuracy: 0.8600 - val_loss: 0.2769
# Epoch 5/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8644 - loss: 0.2559 - val_accuracy: 0.8770 - val_loss: 0.2583
# Epoch 6/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8804 - loss: 0.2340 - val_accuracy: 0.8891 - val_loss: 0.2443
# Epoch 7/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8952 - loss: 0.2167 - val_accuracy: 0.8988 - val_loss: 0.2336
# Epoch 8/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9055 - loss: 0.2028 - val_accuracy: 0.9044 - val_loss: 0.2251
# Epoch 9/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9121 - loss: 0.1911 - val_accuracy: 0.9085 - val_loss: 0.2184
# Epoch 10/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9177 - loss: 0.1813 - val_accuracy: 0.9116 - val_loss: 0.2129
# Epoch 11/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9228 - loss: 0.1729 - val_accuracy: 0.9130 - val_loss: 0.2085
# Epoch 12/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9282 - loss: 0.1655 - val_accuracy: 0.9158 - val_loss: 0.2048
# Epoch 13/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9318 - loss: 0.1590 - val_accuracy: 0.9175 - val_loss: 0.2017
# Epoch 14/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9348 - loss: 0.1532 - val_accuracy: 0.9182 - val_loss: 0.1992
# Epoch 15/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9368 - loss: 0.1480 - val_accuracy: 0.9200 - val_loss: 0.1971
# Epoch 16/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9393 - loss: 0.1433 - val_accuracy: 0.9210 - val_loss: 0.1954
# Epoch 17/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9419 - loss: 0.1390 - val_accuracy: 0.9207 - val_loss: 0.1939
# Epoch 18/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9438 - loss: 0.1351 - val_accuracy: 0.9203 - val_loss: 0.1928
# Epoch 19/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9452 - loss: 0.1315 - val_accuracy: 0.9203 - val_loss: 0.1918
# Epoch 20/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9461 - loss: 0.1282 - val_accuracy: 0.9213 - val_loss: 0.1911
# Epoch 21/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9479 - loss: 0.1251 - val_accuracy: 0.9210 - val_loss: 0.1905
# Epoch 22/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9492 - loss: 0.1222 - val_accuracy: 0.9217 - val_loss: 0.1900
# Epoch 23/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9504 - loss: 0.1194 - val_accuracy: 0.9220 - val_loss: 0.1897
# Epoch 24/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9518 - loss: 0.1169 - val_accuracy: 0.9224 - val_loss: 0.1896
# Epoch 25/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.1145 - val_accuracy: 0.9234 - val_loss: 0.1895
# Epoch 26/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9542 - loss: 0.1123 - val_accuracy: 0.9245 - val_loss: 0.1895
# Epoch 27/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9552 - loss: 0.1101 - val_accuracy: 0.9248 - val_loss: 0.1896
# Epoch 28/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9565 - loss: 0.1081 - val_accuracy: 0.9245 - val_loss: 0.1898
# Epoch 29/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9575 - loss: 0.1062 - val_accuracy: 0.9255 - val_loss: 0.1900
# Epoch 30/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.1043 - val_accuracy: 0.9252 - val_loss: 0.1904
# Epoch 31/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9608 - loss: 0.1026 - val_accuracy: 0.9248 - val_loss: 0.1907
# Epoch 32/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.1009 - val_accuracy: 0.9238 - val_loss: 0.1912
# Epoch 33/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9627 - loss: 0.0993 - val_accuracy: 0.9224 - val_loss: 0.1916
# Epoch 34/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.0978 - val_accuracy: 0.9224 - val_loss: 0.1922
# Epoch 35/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.0963 - val_accuracy: 0.9220 - val_loss: 0.1927
# Epoch 36/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9639 - loss: 0.0949 - val_accuracy: 0.9213 - val_loss: 0.1933
# Epoch 37/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9644 - loss: 0.0936 - val_accuracy: 0.9217 - val_loss: 0.1940
# Epoch 38/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.0923 - val_accuracy: 0.9217 - val_loss: 0.1946
# Epoch 39/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9657 - loss: 0.0910 - val_accuracy: 0.9220 - val_loss: 0.1953
# Epoch 40/40
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9662 - loss: 0.0898 - val_accuracy: 0.9220 - val_loss: 0.1961

# %% [markdown]
# Model Evaluation:
#
# It plots the training and validation loss and accuracy over epochs to visualize the model's learning progress.

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
P_train = ((model.predict(X_train) > 0) * 1.0).flatten()
P_test = ((model.predict(X_test) > 0) * 1.0).flatten()
# Out:
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
cm = confusion_matrix(Y_train, P_train, normalize='true')
cm
# Out:
# array([[0.99037199, 0.00962801],
#        [0.09777778, 0.90222222]])

# %%
# Scikit-Learn is transitioning to V1 but it's not available on Colab
# The changes modify how confusion matrices are plotted
def plot_cm(cm):
  classes = ['negative', 'positive']
  df_cm = pd.DataFrame(cm, index=classes, columns=classes)
  ax = sn.heatmap(df_cm, annot=True, fmt='g')
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Target")

plot_cm(cm)

# %%
cm_test = confusion_matrix(Y_test, P_test, normalize='true')
plot_cm(cm_test)
print(cm_test)
# Out:
# [[0.96556177 0.03443823]
#  [0.25044405 0.74955595]]

# %%
Pr_train = model.predict(X_train)
Pr_test = model.predict(X_test)
print("Train AUC:", roc_auc_score(Y_train, Pr_train))
print("Test AUC:", roc_auc_score(Y_test, Pr_test))
# Out:
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Train AUC: 0.994879001539833
# Test AUC: 0.9534219929059088

# %%
print("Train F1:", f1_score(Y_train, P_train))
print("Test F1:", f1_score(Y_test, P_test))
# Out:
# Train F1: 0.9306590257879657
# Test F1: 0.7924882629107981

# %%
model.layers  #returns a list of all the layers in neural network model.
# It provides access to the individual layers within the model, allowing you to inspect their properties, weights, and perform various operations on them.
# Out:
# [<InputLayer name=input_layer, built=True>, <Dense name=dense, built=True>]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-3.652016 ],
#         [ 3.3592105],
#         [-1.6247803],
#         ...,
#         [ 1.9565585],
#         [ 1.4308212],
#         [-2.8575644]], dtype=float32),
#  array([-0.2316651], dtype=float32)]

# %%
w = model.layers[1].get_weights()[0]

# %% [markdown]
# Word Importance Analysis:
#
# It extracts the weights of the model's dense layer, which represent the importance of each word in predicting sentiment.
#
# It identifies and prints the most positive and negative words based on their weights, providing insights into the factors driving sentiment predictions.

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'jetblue': np.int64(972),
#  'thanks': np.int64(1724),
#  'for': np.int64(749),
#  'having': np.int64(851),
#  'us': np.int64(1860),
#  'hang': np.int64(834),
#  'out': np.int64(1263),
#  'at': np.int64(193),
#  'tampa': np.int64(1706),
#  'airport': np.int64(121),
#  'forever': np.int64(752),
#  'today': np.int64(1764),
#  'it': np.int64(963),
#  'really': np.int64(1420),
#  'been': np.int64(239),
#  'an': np.int64(146),
#  'awesome': np.int64(213),
#  'experience': np.int64(650),
#  'americanair': np.int64(142),
#  'was': np.int64(1897),
#  'told': np.int64(1767),
#  'you': np.int64(1992),
#  'could': np.int64(446),
#  'only': np.int64(1246),
#  'refund': np.int64(1434),
#  'me': np.int64(1109),
#  'the': np.int64(1728),
#  'cost': np.int64(442),
#  'of': np.int64(1225),
#  'my': np.int64(1180),
#  'original': np.int64(1255),
#  'return': np.int64(1476),
#  'flight': np.int64(722),
#  'note': np.int64(1212),
#  'had': np.int64(824),
#  'booked': np.int64(268),
#  'more': np.int64(1165),
#  'expensive': np.int64(649),
#  'everyone': np.int64(631),
#  'else': np.int64(597),
#  'outstanding': np.int64(1267),
#  'united': np.int64(1843),
#  'denver': np.int64(511),
#  'to': np.int64(1763),
#  'austin': np.int64(203),
#  'still': np.int64(1659),
#  'on': np.int64(1240),
#  'ground': np.int64(816),
#  'issue': np.int64(960),
#  'is': np.int64(958),
#  'lack': np.int64(998),
#  'announcement': np.int64(150),
#  'made': np.int64(1088),
#  'so': np.int64(1607),
#  'late': np.int64(1009),
#  'when': np.int64(1928),
#  'gate': np.int64(789),
#  'agent': np.int64(112),
#  'there': np.int64(1732),
#  'over': np.int64(1268),
#  'hour': np.int64(895),
#  'southwestair': np.int64(1627),
#  'hold': np.int64(878),
#  '30': np.int64(37),
#  'min': np.int64(1142),
#  'trying': np.int64(1805),
#  'rebook': np.int64(1423),
#  'cancelled': np.int64(311),
#  'flightled': np.int64(730),
#  'help': np.int64(863),
#  'from': np.int64(769),
#  'phl': np.int64(1309),
#  'dal': np.int64(480),
#  'rebooked': np.int64(1424),
#  'tomorrow': np.int64(1768),
#  'now': np.int64(1218),
#  'that': np.int64(1726),
#  'again': np.int64(110),
#  'usairways': np.int64(1862),
#  'phone': np.int64(1312),
#  'called': np.int64(304),
#  'number': np.int64(1219),
#  'and': np.int64(147),
#  'she': np.int64(1562),
#  'picked': np.int64(1317),
#  'up': np.int64(1851),
#  'almost': np.int64(130),
#  'immediately': np.int64(924),
#  'just': np.int64(979),
#  'sent': np.int64(1547),
#  'another': np.int64(153),
#  'drink': np.int64(574),
#  'think': np.int64(1737),
#  'have': np.int64(849),
#  'free': np.int64(761),
#  'drinks': np.int64(575),
#  'anyone': np.int64(160),
#  'guys': np.int64(822),
#  'off': np.int64(1226),
#  'if': np.int64(919),
#  'every': np.int64(630),
#  'employees': np.int64(605),
#  'would': np.int64(1970),
#  'making': np.int64(1095),
#  'effort': np.int64(595),
#  'credit': np.int64(462),
#  'where': np.int64(1929),
#  'due': np.int64(581),
#  'delayed': np.int64(502),
#  'hours': np.int64(896),
#  'instead': np.int64(950),
#  've': np.int64(1874),
#  '55': np.int64(58),
#  'mins': np.int64(1146),
#  'about': np.int64(75),
#  'flighted': np.int64(726),
#  'international': np.int64(952),
#  'am': np.int64(138),
#  'country': np.int64(452),
#  'can': np.int64(309),
#  'leave': np.int64(1015),
#  'call': np.int64(302),
#  'back': np.int64(217),
#  'got': np.int64(812),
#  'worked': np.int64(1958),
#  'trip': np.int64(1797),
#  'pay': np.int64(1294),
#  'extra': np.int64(660),
#  'though': np.int64(1744),
#  'not': np.int64(1210),
#  'easy': np.int64(592),
#  'poor': np.int64(1350),
#  'did': np.int64(531),
#  'report': np.int64(1449),
#  'updated': np.int64(1853),
#  'info': np.int64(944),
#  'don': np.int64(566),
#  'know': np.int64(992),
#  'how': np.int64(899),
#  'reach': np.int64(1414),
#  'them': np.int64(1730),
#  'without': np.int64(1948),
#  'super': np.int64(1680),
#  'long': np.int64(1059),
#  'wait': np.int64(1886),
#  'your': np.int64(1994),
#  'main': np.int64(1090),
#  'use': np.int64(1864),
#  'voucher': np.int64(1884),
#  'book': np.int64(267),
#  'last': np.int64(1008),
#  'lines': np.int64(1040),
#  'are': np.int64(174),
#  'busy': np.int64(294),
#  'may': np.int64(1105),
#  'go': np.int64(804),
#  'wife': np.int64(1938),
#  'flt': np.int64(738),
#  'via': np.int64(1877),
#  'dfw': np.int64(528),
#  'bought': np.int64(274),
#  'swa': np.int64(1690),
#  'get': np.int64(794),
#  'her': np.int64(867),
#  'home': np.int64(881),
#  'dm': np.int64(556),
#  'plz': np.int64(1343),
#  'course': np.int64(454),
#  'but': np.int64(295),
#  'they': np.int64(1734),
#  'were': np.int64(1920),
#  'as': np.int64(183),
#  'why': np.int64(1936),
#  'getting': np.int64(796),
#  'put': np.int64(1397),
#  'by': np.int64(298),
#  'people': np.int64(1300),
#  'calling': np.int64(305),
#  'platinum': np.int64(1335),
#  'desk': np.int64(522),
#  'thankfully': np.int64(1723),
#  'lounge': np.int64(1071),
#  'next': np.int64(1197),
#  'door': np.int64(569),
#  'impressed': np.int64(927),
#  'thank': np.int64(1722),
#  'with': np.int64(1946),
#  'passbook': np.int64(1284),
#  'all': np.int64(125),
#  'works': np.int64(1961),
#  'much': np.int64(1176),
#  'better': np.int64(247),
#  'happening': np.int64(839),
#  'delta': np.int64(508),
#  'took': np.int64(1771),
#  'care': np.int64(319),
#  'purchase': np.int64(1394),
#  'ticket': np.int64(1752),
#  'check': np.int64(353),
#  'in': np.int64(930),
#  'bag': np.int64(221),
#  'however': np.int64(900),
#  'being': np.int64(242),
#  'charged': np.int64(348),
#  '25': np.int64(30),
#  'dollars': np.int64(564),
#  'domestic': np.int64(565),
#  'heard': np.int64(858),
#  'charge': np.int64(347),
#  '1st': np.int64(20),
#  'seats': np.int64(1530),
#  'no': np.int64(1203),
#  'need': np.int64(1189),
#  'be': np.int64(234),
#  'loyal': np.int64(1080),
#  'jb': np.int64(970),
#  'customer': np.int64(473),
#  'anymore': np.int64(159),
#  'already': np.int64(133),
#  'spoke': np.int64(1638),
#  'line': np.int64(1039),
#  'support': np.int64(1682),
#  'wasn': np.int64(1898),
#  'delay': np.int64(501),
#  'engine': np.int64(609),
#  'needed': np.int64(1190),
#  'makes': np.int64(1094),
#  'person': np.int64(1305),
#  'stand': np.int64(1644),
#  'pilot': np.int64(1319),
#  'or': np.int64(1252),
#  'paperwork': np.int64(1279),
#  'fix': np.int64(716),
#  'problem': np.int64(1377),
#  'fixed': np.int64(717),
#  'ago': np.int64(114),
#  'set': np.int64(1554),
#  'days': np.int64(488),
#  'hoping': np.int64(888),
#  'won': np.int64(1950),
#  'filled': np.int64(705),
#  'because': np.int64(237),
#  'link': np.int64(1041),
#  'doesn': np.int64(560),
#  'work': np.int64(1957),
#  'amp': np.int64(145),
#  'asked': np.int64(187),
#  'many': np.int64(1100),
#  'questions': np.int64(1402),
#  'might': np.int64(1136),
#  'should': np.int64(1568),
#  'seattle': np.int64(1531),
#  'strand': np.int64(1666),
#  'someone': np.int64(1615),
#  'city': np.int64(366),
#  'luggage': np.int64(1085),
#  'aa': np.int64(73),
#  'want': np.int64(1893),
#  'earn': np.int64(588),
#  'business': np.int64(293),
#  'guess': np.int64(819),
#  'needs': np.int64(1191),
#  'their': np.int64(1729),
#  'shit': np.int64(1563),
#  'together': np.int64(1766),
#  'counter': np.int64(450),
#  'catch': np.int64(326),
#  'flights': np.int64(733),
#  'http': np.int64(903),
#  'co': np.int64(383),
#  'passengers': np.int64(1287),
#  'sitting': np.int64(1588),
#  'plane': np.int64(1327),
#  'two': np.int64(1817),
#  'cmh': np.int64(381),
#  'other': np.int64(1259),
#  'left': np.int64(1018),
#  'usairwaysfail': np.int64(1863),
#  'hrs': np.int64(902),
#  'months': np.int64(1164),
#  'supposed': np.int64(1684),
#  'mom': np.int64(1158),
#  'whose': np.int64(1935),
#  'very': np.int64(1876),
#  'upset': np.int64(1858),
#  'crews': np.int64(464),
#  'surprised': np.int64(1687),
#  'arrive': np.int64(179),
#  'fuck': np.int64(775),
#  'this': np.int64(1740),
#  'will': np.int64(1940),
#  'never': np.int64(1192),
#  'bad': np.int64(218),
#  'weather': np.int64(1909),
#  'multiple': np.int64(1177),
#  'has': np.int64(844),
#  'time': np.int64(1757),
#  'reservation': np.int64(1461),
#  'cant': np.int64(315),
#  'through': np.int64(1747),
#  'woman': np.int64(1949),
#  'who': np.int64(1932),
#  'working': np.int64(1960),
#  'find': np.int64(708),
#  'tonight': np.int64(1769),
#  'exec': np.int64(643),
#  'online': np.int64(1245),
#  'clear': np.int64(372),
#  'amazing': np.int64(139),
#  'officially': np.int64(1231),
#  'favorite': np.int64(686),
#  'airline': np.int64(118),
#  'day': np.int64(487),
#  'like': np.int64(1036),
#  'waited': np.int64(1887),
#  'bags': np.int64(223),
#  'coming': np.int64(394),
#  'ahead': np.int64(115),
#  'live': np.int64(1047),
#  'premium': np.int64(1366),
#  'route': np.int64(1490),
#  'lhr': np.int64(1030),
#  'well': np.int64(1918),
#  'didn': np.int64(532),
#  'then': np.int64(1731),
#  'airplane': np.int64(120),
#  'worst': np.int64(1967),
#  'fly': np.int64(739),
#  'ever': np.int64(629),
#  'train': np.int64(1782),
#  'attendants': np.int64(199),
#  'monday': np.int64(1161),
#  're': np.int64(1413),
#  'haven': np.int64(850),
#  'any': np.int64(158),
#  'idea': np.int64(917),
#  'what': np.int64(1924),
#  '200': np.int64(22),
#  'couldn': np.int64(447),
#  'even': np.int64(626),
#  'give': np.int64(798),
#  'food': np.int64(748),
#  'comp': np.int64(399),
#  'take': np.int64(1698),
#  'stranded': np.int64(1667),
#  'flying': np.int64(743),
#  'new': np.int64(1194),
#  'we': np.int64(1908),
#  'stuck': np.int64(1668),
#  'rather': np.int64(1411),
#  'than': np.int64(1721),
#  'broken': np.int64(281),
#  'charlotte': np.int64(351),
#  'service': np.int64(1552),
#  'agents': np.int64(113),
#  'kind': np.int64(989),
#  'way': np.int64(1906),
#  'hopefully': np.int64(887),
#  'future': np.int64(785),
#  'different': np.int64(536),
#  'procedure': np.int64(1379),
#  'car': np.int64(317),
#  'seat': np.int64(1527),
#  'lost': np.int64(1068),
#  'reimburse': np.int64(1440),
#  'one': np.int64(1243),
#  'child': np.int64(361),
#  'baggage': np.int64(222),
#  'handlers': np.int64(831),
#  'totally': np.int64(1774),
#  'our': np.int64(1262),
#  'barely': np.int64(226),
#  'run': np.int64(1502),
#  'connect': np.int64(425),
#  'den': np.int64(509),
#  'came': np.int64(307),
#  'mail': np.int64(1089),
#  'early': np.int64(587),
#  'bird': np.int64(254),
#  'great': np.int64(815),
#  'first': np.int64(713),
#  'crew': np.int64(463),
#  'takes': np.int64(1701),
#  'overhead': np.int64(1270),
#  'bin': np.int64(252),
#  'space': np.int64(1628),
#  'paying': np.int64(1295),
#  'customers': np.int64(474),
#  'annoyed': np.int64(151),
#  'stay': np.int64(1656),
#  'please': np.int64(1338),
#  'which': np.int64(1930),
#  'name': np.int64(1183),
#  'tag': np.int64(1697),
#  '11': np.int64(6),
#  'planes': np.int64(1328),
#  '50': np.int64(55),
#  'its': np.int64(967),
#  '10': np.int64(2),
#  '20': np.int64(21),
#  'tarmac': np.int64(1707),
#  'going': np.int64(807),
#  'compensate': np.int64(403),
#  'companion': np.int64(400),
#  'pass': np.int64(1283),
#  'ridiculous': np.int64(1482),
#  'hadn': np.int64(825),
#  'stopped': np.int64(1662),
#  'hotels': np.int64(894),
#  'non': np.int64(1205),
#  'solve': np.int64(1611),
#  'miss': np.int64(1152),
#  'funeral': np.int64(782),
#  'suck': np.int64(1673),
#  'newark': np.int64(1195),
#  'checked': np.int64(354),
#  'under': np.int64(1830),
#  'too': np.int64(1770),
#  'happy': np.int64(841),
#  'enter': np.int64(613),
#  'hey': np.int64(869),
#  'remember': np.int64(1445),
#  'do': np.int64(558),
#  'email': np.int64(599),
#  'gotten': np.int64(814),
#  'yet': np.int64(1989),
#  'delays': np.int64(504),
#  'little': np.int64(1046),
#  'communication': np.int64(398),
#  'goes': np.int64(806),
#  'nice': np.int64(1199),
#  'routes': np.int64(1491),
#  'jet': np.int64(971),
#  'blue': np.int64(261),
#  'southwest': np.int64(1626),
#  'least': np.int64(1014),
#  'treat': np.int64(1793),
#  'properly': np.int64(1387),
#  'heads': np.int64(856),
#  'arrived': np.int64(180),
#  'those': np.int64(1743),
#  'aren': np.int64(176),
#  'claim': np.int64(367),
#  'point': np.int64(1345),
#  'gt': np.int64(818),
#  'after': np.int64(108),
#  'planned': np.int64(1330),
#  'departure': np.int64(516),
#  'california': np.int64(301),
#  'here': np.int64(868),
#  'originally': np.int64(1256),
#  'keeping': np.int64(982),
#  'safe': np.int64(1507),
#  'sister': np.int64(1585),
#  'reply': np.int64(1448),
#  'ur': np.int64(1859),
#  'services': np.int64(1553),
#  '18': np.int64(15),
#  'response': np.int64(1472),
#  'lousy': np.int64(1072),
#  'unitedairlines': np.int64(1844),
#  'following': np.int64(747),
#  'ice': np.int64(913),
#  'front': np.int64(770),
#  'landed': np.int64(1003),
#  'information': np.int64(945),
#  'saw': np.int64(1517),
#  'helpful': np.int64(865),
#  'specific': np.int64(1632),
#  'cs': np.int64(468),
#  'look': np.int64(1061),
#  'apologize': np.int64(166),
#  'trouble': np.int64(1799),
#  'buffalo': np.int64(288),
#  'jfk': np.int64(974),
#  'figured': np.int64(701),
#  'anything': np.int64(161),
#  'make': np.int64(1093),
#  'll': np.int64(1049),
#  'excuses': np.int64(642),
#  'hi': np.int64(870),
#  'im': np.int64(921),
#  'speak': np.int64(1629),
#  'travel': np.int64(1787),
#  'minor': np.int64(1145),
#  'keeps': np.int64(983),
#  'advise': np.int64(105),
#  'website': np.int64(1911),
#  'wont': np.int64(1954),
#  'allow': np.int64(127),
#  'thx': np.int64(1751),
#  'social': np.int64(1608),
#  'media': np.int64(1116),
#  'memphis': np.int64(1122),
#  'something': np.int64(1616),
#  'also': np.int64(134),
#  'useless': np.int64(1867),
#  'canned': np.int64(313),
#  '1k': np.int64(18),
#  'let': np.int64(1024),
#  'kids': np.int64(987),
#  'board': np.int64(263),
#  'wish': np.int64(1945),
#  'team': np.int64(1710),
#  'member': np.int64(1120),
#  'pick': np.int64(1316),
#  'alone': np.int64(131),
#  'clt': np.int64(378),
#  'gonna': np.int64(810),
#  'connection': np.int64(428),
#  'ua': np.int64(1821),
#  'change': np.int64(341),
#  'music': np.int64(1178),
#  'leaving': np.int64(1017),
#  'morning': np.int64(1166),
#  'auto': np.int64(204),
#  'tuesday': np.int64(1807),
#  'night': np.int64(1200),
#  'horrendous': np.int64(889),
#  'flown': np.int64(737),
#  'come': np.int64(391),
#  'pathetic': np.int64(1290),
#  'waiting': np.int64(1888),
#  'yesterday': np.int64(1988),
#  'class': np.int64(368),
#  'passenger': np.int64(1286),
#  'win': np.int64(1942),
#  'lt': np.int64(1082),
#  'mind': np.int64(1143),
#  'states': np.int64(1654),
#  'maintenance': np.int64(1091),
#  'app': np.int64(168),
#  'says': np.int64(1520),
#  'arriving': np.int64(182),
#  'aircraft': np.int64(117),
#  'tell': np.int64(1713),
#  'unfriendly': np.int64(1839),
#  'right': np.int64(1483),
#  'whole': np.int64(1934),
#  'form': np.int64(754),
#  'before': np.int64(240),
#  'direct': np.int64(539),
#  'address': np.int64(99),
#  'plans': np.int64(1332),
#  'system': np.int64(1695),
#  'reflight': np.int64(1433),
#  'booking': np.int64(269),
#  'problems': np.int64(1378),
#  'disconnect': np.int64(547),
#  'between': np.int64(248),
#  'face': np.int64(665),
#  'enough': np.int64(612),
#  'miles': np.int64(1139),
#  'enjoy': np.int64(611),
#  'perfect': np.int64(1302),
#  'coffee': np.int64(387),
#  'tracking': np.int64(1780),
#  'tells': np.int64(1715),
#  'nothing': np.int64(1214),
#  'less': np.int64(1022),
#  'easily': np.int64(590),
#  'company': np.int64(401),
#  'experienced': np.int64(651),
#  'personal': np.int64(1306),
#  'caused': np.int64(329),
#  'ruining': np.int64(1500),
#  'ashamed': np.int64(185),
#  'gave': np.int64(791),
#  'wrong': np.int64(1974),
#  'nothappy': np.int64(1213),
#  'vouchers': np.int64(1885),
#  'runway': np.int64(1504),
#  'saturday': np.int64(1515),
#  'bwi': np.int64(297),
#  'appreciate': np.int64(171),
#  'power': np.int64(1359),
#  'laptop': np.int64(1005),
#  'iphone': np.int64(957),
#  'missing': np.int64(1154),
#  'good': np.int64(811),
#  'holder': np.int64(879),
#  'conditions': np.int64(417),
#  'arrival': np.int64(178),
#  'de': np.int64(491),
#  'icing': np.int64(914),
#  'three': np.int64(1746),
#  'far': np.int64(679),
#  'sure': np.int64(1685),
#  'taking': np.int64(1702),
#  '15': np.int64(11),
#  '12': np.int64(7),
#  '40': np.int64(49),
#  '45': np.int64(52),
#  'minutes': np.int64(1149),
#  'jetway': np.int64(973),
#  'hotel': np.int64(893),
#  '32': np.int64(42),
#  'counting': np.int64(451),
#  'gotta': np.int64(813),
#  'record': np.int64(1430),
#  'air': np.int64(116),
#  'delivered': np.int64(506),
#  'destination': np.int64(524),
#  'frequent': np.int64(763),
#  'traveler': np.int64(1789),
#  'treated': np.int64(1794),
#  'offer': np.int64(1227),
#  'pls': np.int64(1341),
#  'start': np.int64(1648),
#  'luv': np.int64(1086),
#  'ya': np.int64(1978),
#  'finally': np.int64(707),
#  'nashville': np.int64(1184),
#  'answers': np.int64(157),
#  'away': np.int64(212),
#  'chicago': np.int64(359),
#  'drove': np.int64(580),
#  'prepared': np.int64(1367),
#  'bringing': np.int64(279),
#  'does': np.int64(559),
#  'sense': np.int64(1546),
#  'yay': np.int64(1980),
#  'nuts': np.int64(1221),
#  'cold': np.int64(388),
#  'eventually': np.int64(628),
#  'explained': np.int64(655),
#  'virginamerica': np.int64(1881),
#  'understanding': np.int64(1835),
#  'helped': np.int64(864),
#  'best': np.int64(246),
#  'lady': np.int64(999),
#  'advance': np.int64(103),
#  '24': np.int64(28),
#  'prior': np.int64(1373),
#  'tried': np.int64(1796),
#  'earlier': np.int64(586),
#  'wanted': np.int64(1894),
#  '300': np.int64(38),
#  'fees': np.int64(693),
#  'sfo': np.int64(1557),
#  'say': np.int64(1518),
#  'consistent': np.int64(432),
#  'high': np.int64(871),
#  'quality': np.int64(1400),
#  'keep': np.int64(981),
#  'quick': np.int64(1404),
#  'serious': np.int64(1548),
#  'question': np.int64(1401),
#  'showing': np.int64(1573),
#  'place': np.int64(1324),
#  'fyi': np.int64(786),
#  'dropped': np.int64(579),
#  'able': np.int64(74),
#  'conf': np.int64(418),
#  'appreciated': np.int64(172),
#  'suppose': np.int64(1683),
#  'til': np.int64(1755),
#  'glad': np.int64(802),
#  'damaged': np.int64(483),
#  'answer': np.int64(154),
#  'hung': np.int64(909),
#  'disappointed': np.int64(543),
#  'losing': np.int64(1066),
#  'fill': np.int64(704),
#  'soon': np.int64(1619),
#  'land': np.int64(1002),
#  'hope': np.int64(886),
#  'feedback': np.int64(690),
#  'virgin': np.int64(1880),
#  'went': np.int64(1919),
#  'smooth': np.int64(1602),
#  'ride': np.int64(1481),
#  'wow': np.int64(1972),
#  'thinking': np.int64(1738),
#  'same': np.int64(1512),
#  'ps': np.int64(1391),
#  'overnight': np.int64(1271),
#  'meet': np.int64(1117),
#  'either': np.int64(596),
#  'connections': np.int64(429),
#  'tx': np.int64(1818),
#  'see': np.int64(1535),
#  'year': np.int64(1983),
#  'love': np.int64(1073),
#  'consider': np.int64(430),
#  'fare': np.int64(680),
#  'price': np.int64(1370),
#  'try': np.int64(1804),
#  'father': np.int64(684),
#  'loved': np.int64(1075),
#  'likely': np.int64(1037),
#  'slow': np.int64(1599),
#  'internet': np.int64(953),
#  'addressed': np.int64(100),
#  'fee': np.int64(689),
#  'yes': np.int64(1987),
#  'cust': np.int64(472),
#  'svc': np.int64(1688),
#  'said': np.int64(1510),
#  'evening': np.int64(627),
#  'further': np.int64(784),
#  'both': np.int64(272),
#  'during': np.int64(583),
#  'broke': np.int64(280),
#  'open': np.int64(1248),
#  'camera': np.int64(308),
#  'read': np.int64(1416),
#  'believe': np.int64(243),
#  'incident': np.int64(932),
#  'fault': np.int64(685),
#  'sw': np.int64(1689),
#  'done': np.int64(567),
#  'ive': np.int64(968),
#  'boarding': np.int64(265),
#  'catering': np.int64(327),
#  'always': np.int64(137),
#  'nightmare': np.int64(1201),
#  'fail': np.int64(667),
#  'kidding': np.int64(986),
#  'talked': np.int64(1704),
#  'human': np.int64(906),
#  'asking': np.int64(188),
#  'follow': np.int64(745),
#  'vacation': np.int64(1871),
#  'finish': np.int64(712),
#  'some': np.int64(1612),
#  'text': np.int64(1720),
#  'carrier': np.int64(322),
#  'card': np.int64(318),
#  'nope': np.int64(1208),
#  'apparently': np.int64(169),
#  'times': np.int64(1759),
#  'wtf': np.int64(1976),
#  'looks': np.int64(1064),
#  'handling': np.int64(832),
#  'connecting': np.int64(427),
#  'thru': np.int64(1749),
#  'impossible': np.int64(926),
#  'actually': np.int64(94),
#  'final': np.int64(706),
#  'attitude': np.int64(201),
#  'these': np.int64(1733),
#  'mco': np.int64(1107),
#  'iad': np.int64(911),
#  'fingers': np.int64(711),
#  'crossed': np.int64(466),
#  'four': np.int64(758),
#  'meeting': np.int64(1118),
#  'atlanta': np.int64(195),
#  'slept': np.int64(1598),
#  'security': np.int64(1534),
#  'onto': np.int64(1247),
#  'crying': np.int64(467),
#  'baby': np.int64(216),
#  'situation': np.int64(1589),
#  'drop': np.int64(578),
#  'incredibly': np.int64(939),
#  'unacceptable': np.int64(1826),
#  'issues': np.int64(962),
#  'based': np.int64(227),
#  'things': np.int64(1736),
#  'control': np.int64(438),
#  'wifi': np.int64(1939),
#  'tv': np.int64(1811),
#  'double': np.int64(571),
#  'comment': np.int64(395),
#  'anywhere': np.int64(163),
#  'south': np.int64(1625),
#  'florida': np.int64(736),
#  'gone': np.int64(809),
#  'hello': np.int64(862),
#  'forgot': np.int64(753),
#  'thought': np.int64(1745),
#  'mosaic': np.int64(1167),
#  'perks': np.int64(1304),
#  'part': np.int64(1281),
#  'checking': np.int64(356),
#  '60': np.int64(62),
#  'upgrade': np.int64(1855),
#  'solution': np.int64(1610),
#  'show': np.int64(1571),
#  'track': np.int64(1779),
#  'disappeared': np.int64(542),
#  'dulles': np.int64(582),
#  'lax': np.int64(1010),
#  'thursday': np.int64(1750),
#  'honest': np.int64(882),
#  'reschedule': np.int64(1458),
#  'btw': np.int64(286),
#  'intl': np.int64(954),
#  'flightd': np.int64(725),
#  'area': np.int64(175),
#  'pretty': np.int64(1368),
#  'probably': np.int64(1376),
#  'plus': np.int64(1342),
#  'hearing': np.int64(859),
#  'overbooked': np.int64(1269),
#  'since': np.int64(1582),
#  'file': np.int64(702),
#  'cool': np.int64(439),
#  'pre': np.int64(1362),
#  'thing': np.int64(1735),
#  'single': np.int64(1584),
#  'philly': np.int64(1308),
#  'deal': np.int64(493),
#  'boarded': np.int64(264),
#  'joke': np.int64(977),
#  'computer': np.int64(412),
#  'ing': np.int64(947),
#  'complain': np.int64(406),
#  'public': np.int64(1392),
#  'afternoon': np.int64(109),
#  'six': np.int64(1590),
#  'layover': np.int64(1011),
#  'party': np.int64(1282),
#  'assist': np.int64(191),
#  'except': np.int64(639),
#  'message': np.int64(1127),
#  'trust': np.int64(1803),
#  'bna': np.int64(262),
#  'rdu': np.int64(1412),
#  'most': np.int64(1168),
#  'excellent': np.int64(638),
#  'fa': np.int64(662),
#  'such': np.int64(1672),
#  'warm': np.int64(1896),
#  'onboard': np.int64(1241),
#  'welcome': np.int64(1917),
#  'wonder': np.int64(1951),
#  'hate': np.int64(847),
#  'dealing': np.int64(494),
#  'airlines': np.int64(119),
#  'policies': np.int64(1348),
#  'resolution': np.int64(1465),
#  'jan': np.int64(969),
#  'options': np.int64(1251),
#  'returning': np.int64(1478),
#  'hanging': np.int64(835),
#  'mistake': np.int64(1155),
#  'feel': np.int64(691),
#  'requested': np.int64(1454),
#  'reward': np.int64(1479),
#  'points': np.int64(1346),
#  'used': np.int64(1865),
#  'he': np.int64(852),
#  'refused': np.int64(1438),
#  'screwed': np.int64(1525),
#  'big': np.int64(250),
#  '1hr': np.int64(17),
#  '2nd': np.int64(35),
#  'wouldn': np.int64(1971),
#  'view': np.int64(1879),
#  'changes': np.int64(343),
#  'outside': np.int64(1266),
#  'flightr': np.int64(732),
#  'acceptable': np.int64(81),
#  'entire': np.int64(615),
#  'dca': np.int64(490),
#  'nobody': np.int64(1204),
#  'knows': np.int64(995),
#  'pm': np.int64(1344),
#  'job': np.int64(976),
#  'angry': np.int64(148),
#  'kudos': np.int64(996),
#  'fast': np.int64(682),
#  'congrats': np.int64(424),
#  'systems': np.int64(1696),
#  'down': np.int64(572),
#  'plan': np.int64(1326),
#  'american': np.int64(141),
#  'cuz': np.int64(477),
#  'behind': np.int64(241),
#  'schedule': np.int64(1521),
#  'staff': np.int64(1643),
#  'cabin': np.int64(300),
#  'bos': np.int64(270),
#  'ogg': np.int64(1233),
#  'using': np.int64(1868),
#  'hard': np.int64(842),
#  'given': np.int64(799),
#  'legs': np.int64(1021),
#  'confirm': np.int64(420),
#  'informed': np.int64(946),
#  'flightlation': np.int64(728),
#  'letter': np.int64(1026),
#  'sna': np.int64(1603),
#  'causes': np.int64(330),
#  'provide': np.int64(1388),
#  'transportation': np.int64(1786),
#  'wedding': np.int64(1912),
#  'watch': np.int64(1902),
#  '3hrs': np.int64(46),
#  'sju': np.int64(1592),
#  'worse': np.int64(1966),
#  'handle': np.int64(829),
#  'hangs': np.int64(836),
#  'middle': np.int64(1134),
#  'mad': np.int64(1087),
#  'unhelpful': np.int64(1842),
#  'rude': np.int64(1498),
#  '2hrs': np.int64(34),
#  'beyond': np.int64(249),
#  'spiritairlines': np.int64(1637),
#  'receive': np.int64(1426),
#  'assistance': np.int64(192),
#  'apology': np.int64(167),
#  'disappointing': np.int64(544),
#  'airways': np.int64(123),
#  'answering': np.int64(156),
#  'ugh': np.int64(1823),
#  'ok': np.int64(1235),
#  'insane': np.int64(948),
#  'request': np.int64(1453),
#  'completely': np.int64(410),
#  'paid': np.int64(1275),
#  'group': np.int64(817),
#  'doing': np.int64(563),
#  'while': np.int64(1931),
#  'isn': np.int64(959),
#  'supervisor': np.int64(1681),
#  'regarding': np.int64(1439),
#  'travels': np.int64(1792),
#  'stuff': np.int64(1669),
#  'carry': np.int64(323),
#  'spent': np.int64(1636),
#  'account': np.int64(86),
#  'houston': np.int64(898),
#  'express': np.int64(657),
#  '35': np.int64(43),
#  'additional': np.int64(98),
#  'delivery': np.int64(507),
#  'crazy': np.int64(461),
#  'update': np.int64(1852),
#  'infant': np.int64(942),
#  'children': np.int64(362),
#  'nyc': np.int64(1223),
#  'unbelievable': np.int64(1828),
#  'inbound': np.int64(931),
#  'equipment': np.int64(618),
#  'moving': np.int64(1172),
#  'happens': np.int64(840),
#  'often': np.int64(1232),
#  'la': np.int64(997),
#  'gives': np.int64(800),
#  'absolute': np.int64(77),
#  'found': np.int64(757),
#  'straight': np.int64(1665),
#  'talk': np.int64(1703),
#  'rescheduled': np.int64(1459),
#  'okay': np.int64(1236),
#  'large': np.int64(1006),
#  'real': np.int64(1418),
#  'god': np.int64(805),
#  'man': np.int64(1096),
#  'past': np.int64(1289),
#  'assignment': np.int64(190),
#  'chairman': np.int64(339),
#  'preferred': np.int64(1364),
#  'row': np.int64(1493),
#  'employee': np.int64(604),
#  'telling': np.int64(1714),
#  'fit': np.int64(714),
#  'clearly': np.int64(373),
#  'nah': np.int64(1182),
#  'dont': np.int64(568),
#  'humans': np.int64(907),
#  'respond': np.int64(1469),
#  'relations': np.int64(1444),
#  'midnight': np.int64(1135),
#  'cheers': np.int64(357),
#  'mean': np.int64(1111),
#  'posted': np.int64(1358),
#  'usair': np.int64(1861),
#  '800': np.int64(70),
#  'calls': np.int64(306),
#  'contact': np.int64(433),
#  'understand': np.int64(1833),
#  'missed': np.int64(1153),
#  'mechanical': np.int64(1114),
#  'failure': np.int64(670),
#  'lose': np.int64(1065),
#  '400': np.int64(50),
#  'clients': np.int64(374),
#  'mon': np.int64(1160),
#  'status': np.int64(1655),
#  'match': np.int64(1103),
#  'program': np.int64(1382),
#  'weeks': np.int64(1916),
#  'emailed': np.int64(600),
#  'inside': np.int64(949),
#  'money': np.int64(1162),
#  'phones': np.int64(1313),
#  'suggestions': np.int64(1676),
#  'frustrated': np.int64(772),
#  'items': np.int64(965),
#  'embarrassing': np.int64(602),
#  'third': np.int64(1739),
#  'wheelchair': np.int64(1927),
#  'okc': np.int64(1237),
#  'traveling': np.int64(1791),
#  ...}

# %%
# let's look at the weights for each word
# try it with different threshold values!
threshold=  2

print("Most positive words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight > threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: -x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most positive words:
# thank 9.826883
# thanks 9.397327
# worries 8.671306
# great 8.06363
# love 7.4581647
# awesome 7.401487
# excellent 7.116837
# kudos 6.778479
# amazing 6.449939
# best 6.191763

# %%
print("Most negative words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight < -threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most negative words:
# worst -9.237719
# paid -7.9522896
# not -7.846137
# rude -7.5604215
# disappointed -6.9641957
# nothing -6.9233193
# website -6.7785044
# hung -6.738279
# instead -6.4497733
# weren -6.246088
